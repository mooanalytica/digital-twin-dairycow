# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.7/107.7 GB disk)

# %%
import os
HOME = os.getcwd()
print(HOME)

import cv2
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="8ZKU0UcdYn9XQ5fHYl4s")
project = rf.workspace("shreya-ukhqv").project("cow1-wa2nk")
version = project.version(7)
dataset = version.download("yolov11")
# Out:
# /content
# /content/datasets
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 769.9 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 41.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Cow1-7 in yolov11:: 100%|██████████| 4628/4628 [00:03<00:00, 1431.96it/s]

# %%
from ultralytics import YOLO
HOME = os.getcwd()
# %cd {HOME}

# Load the model
model = YOLO("yolo11s.pt")

# Training
train_results = model.train(
    data="/content/datasets/Cow1-7/data.yaml",
    epochs=90,
    patience=20,
    plots=True,
    #device="cuda",
)
# Out:
# /content
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from google.colab import files
import shutil
import os

folder_path = "/content/runs/detect/train2"
archive_path = shutil.make_archive("folder_archive", 'zip', folder_path)

files.download(archive_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2-384502607.py in <cell line: 0>()
#       4
#       5 folder_path = "/content/runs/detect/train2"
# ----> 6 archive_path = shutil.make_archive("folder_archive", 'zip', folder_path)
#       7
#       8 files.download(archive_path)
#
# /usr/lib/python3.11/shutil.py in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#    1146     save_cwd = None
#    1147     if root_dir is not None:
# -> 1148         stmd = os.stat(root_dir).st_mode
#    1149         if not stat.S_ISDIR(stmd):
#    1150             raise NotADirectoryError(errno.ENOTDIR, 'Not a directory', root_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/train2'
